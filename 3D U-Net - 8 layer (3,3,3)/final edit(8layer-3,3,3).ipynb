# %%
pip install itkwidgets
# Out:
# Requirement already satisfied: itkwidgets in c:\programdata\anaconda3\lib\site-packages (0.32.2)
# Requirement already satisfied: itk-core<5.3,>=5.2.0.post2 in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (5.2.1.post1)
# Requirement already satisfied: ipydatawidgets>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (4.3.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (3.5.3)
# Requirement already satisfied: ipympl>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (0.9.2)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (7.6.3)
# Requirement already satisfied: itk-numerics<5.3,>=5.2.0.post2 in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (5.2.1.post1)
# Requirement already satisfied: itk-filtering<5.3,>=5.2.0.post2 in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (5.2.1.post1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (1.22.4)
# Requirement already satisfied: zstandard in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (0.18.0)
# Requirement already satisfied: colorcet in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (3.0.0)
# Requirement already satisfied: itk-meshtopolydata==0.8.1 in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (0.8.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from itkwidgets) (1.15.0)
# Requirement already satisfied: traittypes>=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipydatawidgets>=4.0.1->itkwidgets) (0.2.1)
# Requirement already satisfied: ipython<9 in c:\programdata\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (7.22.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (8.2.0)
# Requirement already satisfied: traitlets<6 in c:\programdata\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (5.0.5)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (5.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (20.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (4.37.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (2.8.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from colorcet->itkwidgets) (0.4.8)
# Requirement already satisfied: param>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from colorcet->itkwidgets) (1.12.2)
# Requirement already satisfied: tornado>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (6.1)
# Requirement already satisfied: jupyter-client in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (6.1.12)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (2.8.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (52.0.0.post20210125)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.17.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.4.4)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (5.0.6)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (6.3.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl>=0.4.1->itkwidgets) (0.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (0.17.3)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (2.11.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.10.1)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (227)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl>=0.4.1->itkwidgets) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\programdata\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.14.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.1.1)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.4.4)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.5.3)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (2.20)
# Requirement already satisfied: async-generator in c:\programdata\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.10)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.5.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.5.1)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nilearn
# Out:
# Requirement already satisfied: nilearn in c:\programdata\anaconda3\lib\site-packages (0.9.2)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from nilearn) (4.6.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (0.24.1)
# Requirement already satisfied: requests>=2 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (2.25.1)
# Requirement already satisfied: scipy>=1.5 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (1.6.2)
# Requirement already satisfied: pandas>=1.0 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (1.2.4)
# Requirement already satisfied: joblib>=0.15 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (1.0.1)
# Requirement already satisfied: numpy>=1.18 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (1.22.4)
# Requirement already satisfied: nibabel>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (4.0.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from nibabel>=3.0.0->nilearn) (52.0.0.post20210125)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from nibabel>=3.0.0->nilearn) (20.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->nilearn) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->nilearn) (2021.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2->nilearn) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2->nilearn) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2->nilearn) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2->nilearn) (4.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22->nilearn) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->nibabel>=3.0.0->nilearn) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.0->nilearn) (1.15.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow-gpu
# Out:
# Requirement already satisfied: tensorflow-gpu in c:\programdata\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.8.0.dev2021122109)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.25.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (14.0.1)
# Requirement already satisfied: flatbuffers>=1.12 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (52.0.0.post20210125)
# Requirement already satisfied: protobuf>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.20.1)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: gast>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.5.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.46.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.36.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.6.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2020.12.5)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.2.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nibabel
# Out:
# Requirement already satisfied: nibabel in c:\programdata\anaconda3\lib\site-packages (4.0.2)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from nibabel) (20.9)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from nibabel) (1.22.4)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from nibabel) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->nibabel) (2.4.7)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.14.5 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.22.4)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Setting up the environment**

# %% [markdown]
# **Installing the dependencies**

# %%
import numpy as np
import nibabel as nib                                                     
import itk                                                                
import itkwidgets
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
import matplotlib.pyplot as plt
from skimage.util import montage 
from skimage.transform import rotate

# %matplotlib inline
import seaborn as sns

# %%
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing
import cv2
# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
image_path = r"C:/Users/Computing/Desktop/archive/BraTS2021_Training_Data/BraTS2021_00005/BraTS2021_00005_flair.nii.gz"
image_obj = nib.load(image_path)
type(image_obj)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
image_data = image_obj.get_fdata()
print(type(image_data))
image_data.shape
# Out:
# <class 'numpy.ndarray'>
# (240, 240, 155)

# %%
def visualize_3d(layer):
    plt.figure(figsize=(10, 5))
    plt.imshow(image_data[:, :, layer], cmap='gray');
    plt.axis('off')
    return layer

interact(visualize_3d, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
classes_dict = {
    'Normal': 0.,
    'Edema': 1.,
    'Non-enhancing tumor': 2.,
    'Enhancing tumor': 3. 
}

def visualize_3d_labels(layer):
    mask = nib.load(r"C:/Users/Computing/Desktop/archive/BraTS2021_Training_Data/BraTS2021_00005/BraTS2021_00005_seg.nii.gz").get_fdata()
    plt.imshow(mask[:,:,layer])
    plt.axis('off')
    plt.tight_layout()

interact(visualize_3d_labels, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
# DEFINE seg-areas  
SEGMENT_CLASSES = {
    0 : 'NOT tumor',   
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE - RED
    2 : 'EDEMA',  # Green
    3 : 'ENHANCING' # original 4 -> converted into 3 later, Yellow
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
VOLUME_SLICES = 128
VOLUME_START_AT = 22 # first slice of volume that we will include

IMG_SIZE=128

# %%
TRAIN_DATASET_PATH = r"C:/Users/Computing/Desktop/archive/BraTS2021_Training_Data/"

# %%
import os
nSample = os.listdir(TRAIN_DATASET_PATH + 'BraTS2021_00005')
nSample
# Out:
# ['BraTS2021_00005_flair.nii.gz',
#  'BraTS2021_00005_seg.nii.gz',
#  'BraTS2021_00005_t1.nii.gz',
#  'BraTS2021_00005_t1ce.nii.gz',
#  'BraTS2021_00005_t2.nii.gz']

# %%
test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS2021_00005/BraTS2021_00005_flair.nii.gz').get_fdata()
test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS2021_00005/BraTS2021_00005_t1.nii.gz').get_fdata()
test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS2021_00005/BraTS2021_00005_t1ce.nii.gz').get_fdata()
test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS2021_00005/BraTS2021_00005_t2.nii.gz').get_fdata()
test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS2021_00005/BraTS2021_00005_seg.nii.gz').get_fdata()

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w = 25
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_t1ce[:,:,test_image_t1ce.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image t1ce')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_mask[:,:,test_mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_image_t1[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_mask[60:-60,:,:]), 90, resize=True), cmap ='gray')

# %%
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt

# %%
niimg = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS2021_00005/BraTS2021_00005_flair.nii.gz')
nimask = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS2021_00005/BraTS2021_00005_seg.nii.gz')

fig, axes = plt.subplots(nrows=4, figsize=(30, 40))


nlplt.plot_anat(niimg,
                title='BraTS2021_Training_00005_flair.nii plot_anat',
                axes=axes[0])

nlplt.plot_epi(niimg,
               title='BraTS2021_Training_00005_flair.nii plot_epi',
               axes=axes[1])

nlplt.plot_img(niimg,
               title='BraTS2021_Training_00005_flair.nii plot_img',
               axes=axes[2])

nlplt.plot_roi(nimask, 
               title='BraTS2021_Training_00005_flair.nii with mask plot_roi',
               bg_img=niimg, 
               axes=axes[3], cmap='Paired')

plt.show()

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, epsilon=0.00001):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    
    """
    axis = (0,1,2,3)
    dice_numerator = 2. * K.sum(y_true * y_pred, axis=axis) + epsilon
    dice_denominator = K.sum(y_true*y_true, axis=axis) + K.sum(y_pred*y_pred, axis=axis) + epsilon
    return K.mean((dice_numerator)/(dice_denominator))


 
# define per class evaluation of dice coef
# inspired by https://github.com/keras-team/keras/issues/9395
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[0,:,:,:,1] * y_pred[0,:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[0,:,:,:,1])) + K.sum(K.square(y_pred[0,:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[0,:,:,:,2] * y_pred[0,:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[0,:,:,:,2])) + K.sum(K.square(y_pred[0,:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[0,:,:,:,3] * y_pred[0,:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[0,:,:,:,3])) + K.sum(K.square(y_pred[0,:,:,:,3])) + epsilon)


# Computing Precision 
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    
# Computing Sensitivity      
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
IMG_SIZE=128

# %%
TRAIN_DATASET_PATH = 'C:/Users/Computing/Desktop/archive/BraTS2021_Training_Data/'

# %%
def conv_block(input_mat,num_filters,kernel_size,batch_norm):
  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(input_mat)
  if batch_norm:
    X = BatchNormalization()(X)
  
  X = Activation('relu')(X)

  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(X)
  if batch_norm:
    X = BatchNormalization()(X)
  
  X = Activation('relu')(X)
    
  X = add([input_mat,X]);
  
  return X

def Unet_3d(input_img, n_filters = 8, dropout = 0.2, batch_norm = True):

    #Contraction path
    c1 = Conv3D(n_filters, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(input_img)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(n_filters, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(n_filters*2, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(n_filters*2, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = Conv3D(n_filters*4, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(n_filters*4, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = Conv3D(n_filters*8, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(n_filters*8, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)
     
    c5 = Conv3D(n_filters*16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(n_filters*16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)
    
    #Expansive path 
    u6 = Conv3DTranspose(n_filters*8, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(n_filters*8, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(n_filters*8, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c6)
     
    u7 = Conv3DTranspose(n_filters*4, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(n_filters*4, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(n_filters*4, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c7)
     
    u8 = Conv3DTranspose(n_filters*2, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(n_filters*2, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(n_filters*2, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c8)
     
    u9 = Conv3DTranspose(n_filters, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(n_filters, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(n_filters, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c9)
     
    outputs = Conv3D(4, (1, 1, 1), activation='softmax')(c9)
     
    model = Model(inputs=input_img, outputs=outputs)

    return model

# %%
kernel_initializer =  'he_uniform'

# %%
input_layer = Input((128,IMG_SIZE, IMG_SIZE, 2))

model1 = Unet_3d(input_layer)
model1.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4),
                                                                                                                dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, 
                                                                                                                dice_coef_edema ,dice_coef_enhancing] )

model1.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 2)]
#
#  conv3d_95 (Conv3D)             (None, 128, 128, 12  440         ['input_6[0][0]']
#                                 8, 8)
#
#  dropout_45 (Dropout)           (None, 128, 128, 12  0           ['conv3d_95[0][0]']
#                                 8, 8)
#
#  conv3d_96 (Conv3D)             (None, 128, 128, 12  1736        ['dropout_45[0][0]']
#                                 8, 8)
#
#  max_pooling3d_20 (MaxPooling3D  (None, 64, 64, 64,   0          ['conv3d_96[0][0]']
#  )                              8)
#
#  conv3d_97 (Conv3D)             (None, 64, 64, 64,   3472        ['max_pooling3d_20[0][0]']
#                                 16)
#
#  dropout_46 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_97[0][0]']
#                                 16)
#
#  conv3d_98 (Conv3D)             (None, 64, 64, 64,   6928        ['dropout_46[0][0]']
#                                 16)
#
#  max_pooling3d_21 (MaxPooling3D  (None, 32, 32, 32,   0          ['conv3d_98[0][0]']
#  )                              16)
#
#  conv3d_99 (Conv3D)             (None, 32, 32, 32,   13856       ['max_pooling3d_21[0][0]']
#                                 32)
#
#  dropout_47 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_99[0][0]']
#                                 32)
#
#  conv3d_100 (Conv3D)            (None, 32, 32, 32,   27680       ['dropout_47[0][0]']
#                                 32)
#
#  max_pooling3d_22 (MaxPooling3D  (None, 16, 16, 16,   0          ['conv3d_100[0][0]']
#  )                              32)
#
#  conv3d_101 (Conv3D)            (None, 16, 16, 16,   55360       ['max_pooling3d_22[0][0]']
#                                 64)
#
#  dropout_48 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_101[0][0]']
#                                 64)
#
#  conv3d_102 (Conv3D)            (None, 16, 16, 16,   110656      ['dropout_48[0][0]']
#                                 64)
#
#  max_pooling3d_23 (MaxPooling3D  (None, 8, 8, 8, 64)  0          ['conv3d_102[0][0]']
#  )
#
#  conv3d_103 (Conv3D)            (None, 8, 8, 8, 128  221312      ['max_pooling3d_23[0][0]']
#                                 )
#
#  dropout_49 (Dropout)           (None, 8, 8, 8, 128  0           ['conv3d_103[0][0]']
#                                 )
#
#  conv3d_104 (Conv3D)            (None, 8, 8, 8, 128  442496      ['dropout_49[0][0]']
#                                 )
#
#  conv3d_transpose_20 (Conv3DTra  (None, 16, 16, 16,   65600      ['conv3d_104[0][0]']
#  nspose)                        64)
#
#  concatenate_20 (Concatenate)   (None, 16, 16, 16,   0           ['conv3d_transpose_20[0][0]',
#                                 128)                              'conv3d_102[0][0]']
#
#  conv3d_105 (Conv3D)            (None, 16, 16, 16,   221248      ['concatenate_20[0][0]']
#                                 64)
#
#  dropout_50 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_105[0][0]']
#                                 64)
#
#  conv3d_106 (Conv3D)            (None, 16, 16, 16,   110656      ['dropout_50[0][0]']
#                                 64)
#
#  conv3d_transpose_21 (Conv3DTra  (None, 32, 32, 32,   16416      ['conv3d_106[0][0]']
#  nspose)                        32)
#
#  concatenate_21 (Concatenate)   (None, 32, 32, 32,   0           ['conv3d_transpose_21[0][0]',
#                                 64)                               'conv3d_100[0][0]']
#
#  conv3d_107 (Conv3D)            (None, 32, 32, 32,   55328       ['concatenate_21[0][0]']
#                                 32)
#
#  dropout_51 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_107[0][0]']
#                                 32)
#
#  conv3d_108 (Conv3D)            (None, 32, 32, 32,   27680       ['dropout_51[0][0]']
#                                 32)
#
#  conv3d_transpose_22 (Conv3DTra  (None, 64, 64, 64,   4112       ['conv3d_108[0][0]']
#  nspose)                        16)
#
#  concatenate_22 (Concatenate)   (None, 64, 64, 64,   0           ['conv3d_transpose_22[0][0]',
#                                 32)                               'conv3d_98[0][0]']
#
#  conv3d_109 (Conv3D)            (None, 64, 64, 64,   13840       ['concatenate_22[0][0]']
#                                 16)
#
#  dropout_52 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_109[0][0]']
#                                 16)
#
#  conv3d_110 (Conv3D)            (None, 64, 64, 64,   6928        ['dropout_52[0][0]']
#                                 16)
#
#  conv3d_transpose_23 (Conv3DTra  (None, 128, 128, 12  1032       ['conv3d_110[0][0]']
#  nspose)                        8, 8)
#
#  concatenate_23 (Concatenate)   (None, 128, 128, 12  0           ['conv3d_transpose_23[0][0]',
#                                 8, 16)                            'conv3d_96[0][0]']
#
#  conv3d_111 (Conv3D)            (None, 128, 128, 12  3464        ['concatenate_23[0][0]']
#                                 8, 8)
#
#  dropout_53 (Dropout)           (None, 128, 128, 12  0           ['conv3d_111[0][0]']
#                                 8, 8)
#
#  conv3d_112 (Conv3D)            (None, 128, 128, 12  1736        ['dropout_53[0][0]']
#                                 8, 8)
#
#  conv3d_113 (Conv3D)            (None, 128, 128, 12  36          ['conv3d_112[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 1,412,012
# Trainable params: 1,412,012
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import os
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# %%
def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
train_and_test_ids[0]
# Out:
# 'BraTS2021_00000'

# %%
train_ids[0]
# Out:
# 'BraTS2021_00759'

# %%
keras = tf.compat.v1.keras
Sequence = keras.utils.Sequence

class DataGenerator(Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 128, 128))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))

        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii.gz');
            flair = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t1ce.nii.gz');
            ce = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii.gz');
            seg = nib.load(data_path).get_fdata()
        
            for j in range(VOLUME_SLICES):
             X[j+(VOLUME_SLICES*c),:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
             
             
             y[j +VOLUME_SLICES*c,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

        X = X.reshape(1,128,128,128,2)
        y = y.reshape(1,128,128,128)
        # Generate masks
        y[y==4] = 3;
        y = tf.one_hot(y, 4);
        #Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        #Y = np.array(Y).reshape(1,128,128,128)
        return X/np.max(X), y
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
print(len(train_ids))
print(len(val_ids))
print(len(test_ids))
# Out:
# 850
# 251
# 150

# %%
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')
    plt.savefig('data2021.png')
    plt.show()
    
showDataLayout()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
csv_logger = CSVLogger('C:/Users/Computing/Desktop/archive/training.log', separator=',', append=False)


callbacks = [keras.callbacks.EarlyStopping(monitor='loss', min_delta=0,
                               patience=8, verbose=1, mode='auto'),
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=8, min_lr=0.000001, verbose=1),
      keras.callbacks.ModelCheckpoint(filepath = 'C:/Users/Computing/Desktop/archive/3D-UNet-2021model_.{epoch:02d}-{val_loss:.6f}.m5',
                             verbose=1, save_best_only=True, save_weights_only = True),
      csv_logger
    ]

# %%
history =  model1.fit(training_generator,
                     epochs=100,
                     steps_per_epoch=len(train_ids),
                     callbacks= callbacks,
                     validation_data = valid_generator
                     )  
model1.save("C:/Users/Computing/Desktop/archive/model_3dUnet_8layer_2mod.h5")
# Out:
# Epoch 1/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9871 - mean_io_u_5: 0.7531 - dice_coef: 0.3108 - precision: 0.9871 - sensitivity: 0.9870 - specificity: 0.9957 - dice_coef_necrotic: 0.0671 - dice_coef_edema: 0.1370 - dice_coef_enhancing: 0.0452
# Epoch 1: val_loss improved from inf to 0.04863, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.01-0.048626.m5
# 850/850 [==============================] - 295s 347ms/step - loss: 0.0569 - accuracy: 0.9871 - mean_io_u_5: 0.7531 - dice_coef: 0.3108 - precision: 0.9871 - sensitivity: 0.9870 - specificity: 0.9957 - dice_coef_necrotic: 0.0671 - dice_coef_edema: 0.1370 - dice_coef_enhancing: 0.0452 - val_loss: 0.0486 - val_accuracy: 0.9868 - val_mean_io_u_5: 0.7367 - val_dice_coef: 0.3396 - val_precision: 0.9875 - val_sensitivity: 0.9864 - val_specificity: 0.9959 - val_dice_coef_necrotic: 0.0943 - val_dice_coef_edema: 0.1791 - val_dice_coef_enhancing: 0.0901 - lr: 0.0010
# Epoch 2/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9872 - mean_io_u_5: 0.6400 - dice_coef: 0.3680 - precision: 0.9904 - sensitivity: 0.9853 - specificity: 0.9968 - dice_coef_necrotic: 0.1285 - dice_coef_edema: 0.2195 - dice_coef_enhancing: 0.1287
# Epoch 2: val_loss improved from 0.04863 to 0.03892, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.02-0.038923.m5
# 850/850 [==============================] - 305s 359ms/step - loss: 0.0461 - accuracy: 0.9872 - mean_io_u_5: 0.6400 - dice_coef: 0.3680 - precision: 0.9904 - sensitivity: 0.9853 - specificity: 0.9968 - dice_coef_necrotic: 0.1285 - dice_coef_edema: 0.2195 - dice_coef_enhancing: 0.1287 - val_loss: 0.0389 - val_accuracy: 0.9877 - val_mean_io_u_5: 0.5226 - val_dice_coef: 0.4269 - val_precision: 0.9945 - val_sensitivity: 0.9829 - val_specificity: 0.9982 - val_dice_coef_necrotic: 0.1890 - val_dice_coef_edema: 0.3180 - val_dice_coef_enhancing: 0.2042 - lr: 0.0010
# Epoch 3/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9882 - mean_io_u_5: 0.6749 - dice_coef: 0.4075 - precision: 0.9921 - sensitivity: 0.9853 - specificity: 0.9974 - dice_coef_necrotic: 0.1562 - dice_coef_edema: 0.3081 - dice_coef_enhancing: 0.1695
# Epoch 3: val_loss improved from 0.03892 to 0.03406, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.03-0.034063.m5
# 850/850 [==============================] - 293s 345ms/step - loss: 0.0405 - accuracy: 0.9882 - mean_io_u_5: 0.6749 - dice_coef: 0.4075 - precision: 0.9921 - sensitivity: 0.9853 - specificity: 0.9974 - dice_coef_necrotic: 0.1562 - dice_coef_edema: 0.3081 - dice_coef_enhancing: 0.1695 - val_loss: 0.0341 - val_accuracy: 0.9890 - val_mean_io_u_5: 0.8162 - val_dice_coef: 0.4620 - val_precision: 0.9953 - val_sensitivity: 0.9839 - val_specificity: 0.9984 - val_dice_coef_necrotic: 0.2191 - val_dice_coef_edema: 0.3613 - val_dice_coef_enhancing: 0.2705 - lr: 0.0010
# Epoch 4/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9891 - mean_io_u_5: 0.7342 - dice_coef: 0.4514 - precision: 0.9930 - sensitivity: 0.9863 - specificity: 0.9977 - dice_coef_necrotic: 0.1932 - dice_coef_edema: 0.3848 - dice_coef_enhancing: 0.2307
# Epoch 4: val_loss improved from 0.03406 to 0.03197, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.04-0.031967.m5
# 850/850 [==============================] - 286s 336ms/step - loss: 0.0350 - accuracy: 0.9891 - mean_io_u_5: 0.7342 - dice_coef: 0.4514 - precision: 0.9930 - sensitivity: 0.9863 - specificity: 0.9977 - dice_coef_necrotic: 0.1932 - dice_coef_edema: 0.3848 - dice_coef_enhancing: 0.2307 - val_loss: 0.0320 - val_accuracy: 0.9896 - val_mean_io_u_5: 0.7893 - val_dice_coef: 0.5118 - val_precision: 0.9960 - val_sensitivity: 0.9833 - val_specificity: 0.9987 - val_dice_coef_necrotic: 0.2902 - val_dice_coef_edema: 0.4417 - val_dice_coef_enhancing: 0.3181 - lr: 0.0010
# Epoch 5/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9900 - mean_io_u_5: 0.7641 - dice_coef: 0.4928 - precision: 0.9937 - sensitivity: 0.9870 - specificity: 0.9979 - dice_coef_necrotic: 0.2148 - dice_coef_edema: 0.4358 - dice_coef_enhancing: 0.3232
# Epoch 5: val_loss improved from 0.03197 to 0.03006, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.05-0.030061.m5
# 850/850 [==============================] - 286s 336ms/step - loss: 0.0314 - accuracy: 0.9900 - mean_io_u_5: 0.7641 - dice_coef: 0.4928 - precision: 0.9937 - sensitivity: 0.9870 - specificity: 0.9979 - dice_coef_necrotic: 0.2148 - dice_coef_edema: 0.4358 - dice_coef_enhancing: 0.3232 - val_loss: 0.0301 - val_accuracy: 0.9904 - val_mean_io_u_5: 0.8386 - val_dice_coef: 0.5110 - val_precision: 0.9927 - val_sensitivity: 0.9886 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.2091 - val_dice_coef_edema: 0.4246 - val_dice_coef_enhancing: 0.4130 - lr: 0.0010
# Epoch 6/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9907 - mean_io_u_5: 0.8085 - dice_coef: 0.5356 - precision: 0.9933 - sensitivity: 0.9886 - specificity: 0.9978 - dice_coef_necrotic: 0.2310 - dice_coef_edema: 0.4621 - dice_coef_enhancing: 0.4518
# Epoch 6: val_loss improved from 0.03006 to 0.02847, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.06-0.028473.m5
# 850/850 [==============================] - 289s 340ms/step - loss: 0.0298 - accuracy: 0.9907 - mean_io_u_5: 0.8085 - dice_coef: 0.5356 - precision: 0.9933 - sensitivity: 0.9886 - specificity: 0.9978 - dice_coef_necrotic: 0.2310 - dice_coef_edema: 0.4621 - dice_coef_enhancing: 0.4518 - val_loss: 0.0285 - val_accuracy: 0.9908 - val_mean_io_u_5: 0.8338 - val_dice_coef: 0.5451 - val_precision: 0.9940 - val_sensitivity: 0.9882 - val_specificity: 0.9980 - val_dice_coef_necrotic: 0.1970 - val_dice_coef_edema: 0.4448 - val_dice_coef_enhancing: 0.5409 - lr: 0.0010
# Epoch 7/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9913 - mean_io_u_5: 0.8304 - dice_coef: 0.5705 - precision: 0.9938 - sensitivity: 0.9894 - specificity: 0.9980 - dice_coef_necrotic: 0.2611 - dice_coef_edema: 0.4993 - dice_coef_enhancing: 0.5240
# Epoch 7: val_loss improved from 0.02847 to 0.02497, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.07-0.024972.m5
# 850/850 [==============================] - 292s 344ms/step - loss: 0.0266 - accuracy: 0.9913 - mean_io_u_5: 0.8304 - dice_coef: 0.5705 - precision: 0.9938 - sensitivity: 0.9894 - specificity: 0.9980 - dice_coef_necrotic: 0.2611 - dice_coef_edema: 0.4993 - dice_coef_enhancing: 0.5240 - val_loss: 0.0250 - val_accuracy: 0.9921 - val_mean_io_u_5: 0.8586 - val_dice_coef: 0.6070 - val_precision: 0.9941 - val_sensitivity: 0.9906 - val_specificity: 0.9980 - val_dice_coef_necrotic: 0.2674 - val_dice_coef_edema: 0.5751 - val_dice_coef_enhancing: 0.5877 - lr: 0.0010
# Epoch 8/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9918 - mean_io_u_5: 0.8225 - dice_coef: 0.5893 - precision: 0.9941 - sensitivity: 0.9899 - specificity: 0.9981 - dice_coef_necrotic: 0.2787 - dice_coef_edema: 0.5304 - dice_coef_enhancing: 0.5502
# Epoch 8: val_loss did not improve from 0.02497
# 850/850 [==============================] - 285s 335ms/step - loss: 0.0250 - accuracy: 0.9918 - mean_io_u_5: 0.8225 - dice_coef: 0.5893 - precision: 0.9941 - sensitivity: 0.9899 - specificity: 0.9981 - dice_coef_necrotic: 0.2787 - dice_coef_edema: 0.5304 - dice_coef_enhancing: 0.5502 - val_loss: 0.0259 - val_accuracy: 0.9915 - val_mean_io_u_5: 0.8318 - val_dice_coef: 0.6056 - val_precision: 0.9937 - val_sensitivity: 0.9897 - val_specificity: 0.9979 - val_dice_coef_necrotic: 0.3155 - val_dice_coef_edema: 0.4794 - val_dice_coef_enhancing: 0.6300 - lr: 0.0010
# Epoch 9/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9925 - mean_io_u_5: 0.8295 - dice_coef: 0.6186 - precision: 0.9946 - sensitivity: 0.9908 - specificity: 0.9982 - dice_coef_necrotic: 0.3136 - dice_coef_edema: 0.5710 - dice_coef_enhancing: 0.5916
# Epoch 9: val_loss improved from 0.02497 to 0.02392, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.09-0.023922.m5
# 850/850 [==============================] - 289s 340ms/step - loss: 0.0226 - accuracy: 0.9925 - mean_io_u_5: 0.8295 - dice_coef: 0.6186 - precision: 0.9946 - sensitivity: 0.9908 - specificity: 0.9982 - dice_coef_necrotic: 0.3136 - dice_coef_edema: 0.5710 - dice_coef_enhancing: 0.5916 - val_loss: 0.0239 - val_accuracy: 0.9921 - val_mean_io_u_5: 0.8407 - val_dice_coef: 0.6188 - val_precision: 0.9941 - val_sensitivity: 0.9906 - val_specificity: 0.9980 - val_dice_coef_necrotic: 0.3647 - val_dice_coef_edema: 0.5760 - val_dice_coef_enhancing: 0.5366 - lr: 0.0010
# Epoch 10/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9920 - mean_io_u_5: 0.8276 - dice_coef: 0.5974 - precision: 0.9942 - sensitivity: 0.9902 - specificity: 0.9981 - dice_coef_necrotic: 0.2915 - dice_coef_edema: 0.5372 - dice_coef_enhancing: 0.5631
# Epoch 10: val_loss improved from 0.02392 to 0.02201, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.10-0.022014.m5
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0247 - accuracy: 0.9920 - mean_io_u_5: 0.8276 - dice_coef: 0.5974 - precision: 0.9942 - sensitivity: 0.9902 - specificity: 0.9981 - dice_coef_necrotic: 0.2915 - dice_coef_edema: 0.5372 - dice_coef_enhancing: 0.5631 - val_loss: 0.0220 - val_accuracy: 0.9927 - val_mean_io_u_5: 0.8305 - val_dice_coef: 0.6595 - val_precision: 0.9950 - val_sensitivity: 0.9907 - val_specificity: 0.9984 - val_dice_coef_necrotic: 0.3868 - val_dice_coef_edema: 0.5922 - val_dice_coef_enhancing: 0.6608 - lr: 0.0010
# Epoch 11/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9928 - mean_io_u_5: 0.8354 - dice_coef: 0.6299 - precision: 0.9947 - sensitivity: 0.9912 - specificity: 0.9982 - dice_coef_necrotic: 0.3262 - dice_coef_edema: 0.5901 - dice_coef_enhancing: 0.6052
# Epoch 11: val_loss improved from 0.02201 to 0.02092, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.11-0.020925.m5
# 850/850 [==============================] - 280s 330ms/step - loss: 0.0219 - accuracy: 0.9928 - mean_io_u_5: 0.8354 - dice_coef: 0.6299 - precision: 0.9947 - sensitivity: 0.9912 - specificity: 0.9982 - dice_coef_necrotic: 0.3262 - dice_coef_edema: 0.5901 - dice_coef_enhancing: 0.6052 - val_loss: 0.0209 - val_accuracy: 0.9930 - val_mean_io_u_5: 0.8332 - val_dice_coef: 0.6449 - val_precision: 0.9950 - val_sensitivity: 0.9914 - val_specificity: 0.9983 - val_dice_coef_necrotic: 0.3505 - val_dice_coef_edema: 0.5857 - val_dice_coef_enhancing: 0.6453 - lr: 0.0010
# Epoch 12/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9929 - mean_io_u_5: 0.8315 - dice_coef: 0.6406 - precision: 0.9948 - sensitivity: 0.9915 - specificity: 0.9983 - dice_coef_necrotic: 0.3349 - dice_coef_edema: 0.6007 - dice_coef_enhancing: 0.6285
# Epoch 12: val_loss did not improve from 0.02092
# 850/850 [==============================] - 282s 332ms/step - loss: 0.0213 - accuracy: 0.9929 - mean_io_u_5: 0.8315 - dice_coef: 0.6406 - precision: 0.9948 - sensitivity: 0.9915 - specificity: 0.9983 - dice_coef_necrotic: 0.3349 - dice_coef_edema: 0.6007 - dice_coef_enhancing: 0.6285 - val_loss: 0.0214 - val_accuracy: 0.9929 - val_mean_io_u_5: 0.8284 - val_dice_coef: 0.6269 - val_precision: 0.9946 - val_sensitivity: 0.9917 - val_specificity: 0.9982 - val_dice_coef_necrotic: 0.3395 - val_dice_coef_edema: 0.6275 - val_dice_coef_enhancing: 0.5422 - lr: 0.0010
# Epoch 13/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9933 - mean_io_u_5: 0.8442 - dice_coef: 0.6513 - precision: 0.9951 - sensitivity: 0.9918 - specificity: 0.9984 - dice_coef_necrotic: 0.3515 - dice_coef_edema: 0.6206 - dice_coef_enhancing: 0.6347
# Epoch 13: val_loss did not improve from 0.02092
# 850/850 [==============================] - 282s 332ms/step - loss: 0.0202 - accuracy: 0.9933 - mean_io_u_5: 0.8442 - dice_coef: 0.6513 - precision: 0.9951 - sensitivity: 0.9918 - specificity: 0.9984 - dice_coef_necrotic: 0.3515 - dice_coef_edema: 0.6206 - dice_coef_enhancing: 0.6347 - val_loss: 0.0214 - val_accuracy: 0.9932 - val_mean_io_u_5: 0.8659 - val_dice_coef: 0.6452 - val_precision: 0.9950 - val_sensitivity: 0.9919 - val_specificity: 0.9983 - val_dice_coef_necrotic: 0.3511 - val_dice_coef_edema: 0.6465 - val_dice_coef_enhancing: 0.5848 - lr: 0.0010
# Epoch 14/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9932 - mean_io_u_5: 0.8409 - dice_coef: 0.6525 - precision: 0.9951 - sensitivity: 0.9918 - specificity: 0.9984 - dice_coef_necrotic: 0.3551 - dice_coef_edema: 0.6199 - dice_coef_enhancing: 0.6367
# Epoch 14: val_loss improved from 0.02092 to 0.01950, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.14-0.019502.m5
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0204 - accuracy: 0.9932 - mean_io_u_5: 0.8409 - dice_coef: 0.6525 - precision: 0.9951 - sensitivity: 0.9918 - specificity: 0.9984 - dice_coef_necrotic: 0.3551 - dice_coef_edema: 0.6199 - dice_coef_enhancing: 0.6367 - val_loss: 0.0195 - val_accuracy: 0.9935 - val_mean_io_u_5: 0.8459 - val_dice_coef: 0.6842 - val_precision: 0.9950 - val_sensitivity: 0.9924 - val_specificity: 0.9983 - val_dice_coef_necrotic: 0.3614 - val_dice_coef_edema: 0.6708 - val_dice_coef_enhancing: 0.7059 - lr: 0.0010
# Epoch 15/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9932 - mean_io_u_5: 0.8506 - dice_coef: 0.6521 - precision: 0.9951 - sensitivity: 0.9918 - specificity: 0.9984 - dice_coef_necrotic: 0.3601 - dice_coef_edema: 0.6175 - dice_coef_enhancing: 0.6326
# Epoch 15: val_loss did not improve from 0.01950
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0207 - accuracy: 0.9932 - mean_io_u_5: 0.8506 - dice_coef: 0.6521 - precision: 0.9951 - sensitivity: 0.9918 - specificity: 0.9984 - dice_coef_necrotic: 0.3601 - dice_coef_edema: 0.6175 - dice_coef_enhancing: 0.6326 - val_loss: 0.0245 - val_accuracy: 0.9923 - val_mean_io_u_5: 0.8470 - val_dice_coef: 0.6195 - val_precision: 0.9936 - val_sensitivity: 0.9914 - val_specificity: 0.9979 - val_dice_coef_necrotic: 0.2780 - val_dice_coef_edema: 0.5844 - val_dice_coef_enhancing: 0.6177 - lr: 0.0010
# Epoch 16/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9937 - mean_io_u_5: 0.8474 - dice_coef: 0.6700 - precision: 0.9954 - sensitivity: 0.9924 - specificity: 0.9985 - dice_coef_necrotic: 0.3766 - dice_coef_edema: 0.6447 - dice_coef_enhancing: 0.6602
# Epoch 16: val_loss improved from 0.01950 to 0.01950, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.16-0.019499.m5
# 850/850 [==============================] - 284s 333ms/step - loss: 0.0189 - accuracy: 0.9937 - mean_io_u_5: 0.8474 - dice_coef: 0.6700 - precision: 0.9954 - sensitivity: 0.9924 - specificity: 0.9985 - dice_coef_necrotic: 0.3766 - dice_coef_edema: 0.6447 - dice_coef_enhancing: 0.6602 - val_loss: 0.0195 - val_accuracy: 0.9937 - val_mean_io_u_5: 0.8363 - val_dice_coef: 0.6984 - val_precision: 0.9953 - val_sensitivity: 0.9924 - val_specificity: 0.9984 - val_dice_coef_necrotic: 0.4010 - val_dice_coef_edema: 0.6787 - val_dice_coef_enhancing: 0.7156 - lr: 0.0010
# Epoch 17/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9934 - mean_io_u_5: 0.8512 - dice_coef: 0.6635 - precision: 0.9952 - sensitivity: 0.9920 - specificity: 0.9984 - dice_coef_necrotic: 0.3681 - dice_coef_edema: 0.6346 - dice_coef_enhancing: 0.6528
# Epoch 17: val_loss did not improve from 0.01950
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0201 - accuracy: 0.9934 - mean_io_u_5: 0.8512 - dice_coef: 0.6635 - precision: 0.9952 - sensitivity: 0.9920 - specificity: 0.9984 - dice_coef_necrotic: 0.3681 - dice_coef_edema: 0.6346 - dice_coef_enhancing: 0.6528 - val_loss: 0.0206 - val_accuracy: 0.9933 - val_mean_io_u_5: 0.8291 - val_dice_coef: 0.6933 - val_precision: 0.9951 - val_sensitivity: 0.9919 - val_specificity: 0.9984 - val_dice_coef_necrotic: 0.3878 - val_dice_coef_edema: 0.6700 - val_dice_coef_enhancing: 0.7173 - lr: 0.0010
# Epoch 18/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9938 - mean_io_u_5: 0.8480 - dice_coef: 0.6771 - precision: 0.9955 - sensitivity: 0.9925 - specificity: 0.9985 - dice_coef_necrotic: 0.3850 - dice_coef_edema: 0.6528 - dice_coef_enhancing: 0.6722
# Epoch 18: val_loss improved from 0.01950 to 0.01919, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.18-0.019191.m5
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0186 - accuracy: 0.9938 - mean_io_u_5: 0.8480 - dice_coef: 0.6771 - precision: 0.9955 - sensitivity: 0.9925 - specificity: 0.9985 - dice_coef_necrotic: 0.3850 - dice_coef_edema: 0.6528 - dice_coef_enhancing: 0.6722 - val_loss: 0.0192 - val_accuracy: 0.9937 - val_mean_io_u_5: 0.8639 - val_dice_coef: 0.6642 - val_precision: 0.9951 - val_sensitivity: 0.9926 - val_specificity: 0.9984 - val_dice_coef_necrotic: 0.3448 - val_dice_coef_edema: 0.6849 - val_dice_coef_enhancing: 0.6286 - lr: 0.0010
# Epoch 19/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9940 - mean_io_u_5: 0.8541 - dice_coef: 0.6864 - precision: 0.9957 - sensitivity: 0.9928 - specificity: 0.9986 - dice_coef_necrotic: 0.3984 - dice_coef_edema: 0.6680 - dice_coef_enhancing: 0.6807
# Epoch 19: val_loss improved from 0.01919 to 0.01751, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.19-0.017505.m5
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0178 - accuracy: 0.9940 - mean_io_u_5: 0.8541 - dice_coef: 0.6864 - precision: 0.9957 - sensitivity: 0.9928 - specificity: 0.9986 - dice_coef_necrotic: 0.3984 - dice_coef_edema: 0.6680 - dice_coef_enhancing: 0.6807 - val_loss: 0.0175 - val_accuracy: 0.9943 - val_mean_io_u_5: 0.8630 - val_dice_coef: 0.7135 - val_precision: 0.9957 - val_sensitivity: 0.9932 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4436 - val_dice_coef_edema: 0.7055 - val_dice_coef_enhancing: 0.7062 - lr: 0.0010
# Epoch 20/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9945 - mean_io_u_5: 0.8590 - dice_coef: 0.7019 - precision: 0.9960 - sensitivity: 0.9933 - specificity: 0.9987 - dice_coef_necrotic: 0.4195 - dice_coef_edema: 0.6932 - dice_coef_enhancing: 0.6962
# Epoch 20: val_loss did not improve from 0.01751
# 850/850 [==============================] - 283s 332ms/step - loss: 0.0163 - accuracy: 0.9945 - mean_io_u_5: 0.8590 - dice_coef: 0.7019 - precision: 0.9960 - sensitivity: 0.9933 - specificity: 0.9987 - dice_coef_necrotic: 0.4195 - dice_coef_edema: 0.6932 - dice_coef_enhancing: 0.6962 - val_loss: 0.0180 - val_accuracy: 0.9942 - val_mean_io_u_5: 0.8673 - val_dice_coef: 0.6790 - val_precision: 0.9952 - val_sensitivity: 0.9935 - val_specificity: 0.9984 - val_dice_coef_necrotic: 0.3359 - val_dice_coef_edema: 0.6983 - val_dice_coef_enhancing: 0.6831 - lr: 0.0010
# Epoch 21/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9943 - mean_io_u_5: 0.8569 - dice_coef: 0.6958 - precision: 0.9959 - sensitivity: 0.9930 - specificity: 0.9986 - dice_coef_necrotic: 0.4086 - dice_coef_edema: 0.6851 - dice_coef_enhancing: 0.6908
# Epoch 21: val_loss did not improve from 0.01751
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0170 - accuracy: 0.9943 - mean_io_u_5: 0.8569 - dice_coef: 0.6958 - precision: 0.9959 - sensitivity: 0.9930 - specificity: 0.9986 - dice_coef_necrotic: 0.4086 - dice_coef_edema: 0.6851 - dice_coef_enhancing: 0.6908 - val_loss: 0.0197 - val_accuracy: 0.9936 - val_mean_io_u_5: 0.8663 - val_dice_coef: 0.6849 - val_precision: 0.9954 - val_sensitivity: 0.9922 - val_specificity: 0.9985 - val_dice_coef_necrotic: 0.4229 - val_dice_coef_edema: 0.6899 - val_dice_coef_enhancing: 0.6285 - lr: 0.0010
# Epoch 22/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9940 - mean_io_u_5: 0.8554 - dice_coef: 0.6844 - precision: 0.9957 - sensitivity: 0.9926 - specificity: 0.9986 - dice_coef_necrotic: 0.4024 - dice_coef_edema: 0.6663 - dice_coef_enhancing: 0.6705
# Epoch 22: val_loss did not improve from 0.01751
# 850/850 [==============================] - 282s 332ms/step - loss: 0.0183 - accuracy: 0.9940 - mean_io_u_5: 0.8554 - dice_coef: 0.6844 - precision: 0.9957 - sensitivity: 0.9926 - specificity: 0.9986 - dice_coef_necrotic: 0.4024 - dice_coef_edema: 0.6663 - dice_coef_enhancing: 0.6705 - val_loss: 0.0193 - val_accuracy: 0.9938 - val_mean_io_u_5: 0.8357 - val_dice_coef: 0.6705 - val_precision: 0.9950 - val_sensitivity: 0.9930 - val_specificity: 0.9984 - val_dice_coef_necrotic: 0.3491 - val_dice_coef_edema: 0.6761 - val_dice_coef_enhancing: 0.6584 - lr: 0.0010
# Epoch 23/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9943 - mean_io_u_5: 0.8524 - dice_coef: 0.7003 - precision: 0.9959 - sensitivity: 0.9931 - specificity: 0.9987 - dice_coef_necrotic: 0.4205 - dice_coef_edema: 0.6859 - dice_coef_enhancing: 0.6959
# Epoch 23: val_loss improved from 0.01751 to 0.01739, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.23-0.017386.m5
# 850/850 [==============================] - 282s 332ms/step - loss: 0.0169 - accuracy: 0.9943 - mean_io_u_5: 0.8524 - dice_coef: 0.7003 - precision: 0.9959 - sensitivity: 0.9931 - specificity: 0.9987 - dice_coef_necrotic: 0.4205 - dice_coef_edema: 0.6859 - dice_coef_enhancing: 0.6959 - val_loss: 0.0174 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8392 - val_dice_coef: 0.7064 - val_precision: 0.9959 - val_sensitivity: 0.9932 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4491 - val_dice_coef_edema: 0.7001 - val_dice_coef_enhancing: 0.6779 - lr: 0.0010
# Epoch 24/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9945 - mean_io_u_5: 0.8562 - dice_coef: 0.7031 - precision: 0.9961 - sensitivity: 0.9932 - specificity: 0.9987 - dice_coef_necrotic: 0.4227 - dice_coef_edema: 0.6952 - dice_coef_enhancing: 0.6959
# Epoch 24: val_loss did not improve from 0.01739
# 850/850 [==============================] - 282s 332ms/step - loss: 0.0165 - accuracy: 0.9945 - mean_io_u_5: 0.8562 - dice_coef: 0.7031 - precision: 0.9961 - sensitivity: 0.9932 - specificity: 0.9987 - dice_coef_necrotic: 0.4227 - dice_coef_edema: 0.6952 - dice_coef_enhancing: 0.6959 - val_loss: 0.0177 - val_accuracy: 0.9943 - val_mean_io_u_5: 0.8331 - val_dice_coef: 0.7063 - val_precision: 0.9957 - val_sensitivity: 0.9933 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4334 - val_dice_coef_edema: 0.6969 - val_dice_coef_enhancing: 0.6962 - lr: 0.0010
# Epoch 25/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9944 - mean_io_u_5: 0.8604 - dice_coef: 0.7040 - precision: 0.9960 - sensitivity: 0.9932 - specificity: 0.9987 - dice_coef_necrotic: 0.4306 - dice_coef_edema: 0.6897 - dice_coef_enhancing: 0.6970
# Epoch 25: val_loss did not improve from 0.01739
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0169 - accuracy: 0.9944 - mean_io_u_5: 0.8604 - dice_coef: 0.7040 - precision: 0.9960 - sensitivity: 0.9932 - specificity: 0.9987 - dice_coef_necrotic: 0.4306 - dice_coef_edema: 0.6897 - dice_coef_enhancing: 0.6970 - val_loss: 0.0226 - val_accuracy: 0.9929 - val_mean_io_u_5: 0.8693 - val_dice_coef: 0.6471 - val_precision: 0.9944 - val_sensitivity: 0.9918 - val_specificity: 0.9981 - val_dice_coef_necrotic: 0.3699 - val_dice_coef_edema: 0.6222 - val_dice_coef_enhancing: 0.5982 - lr: 0.0010
# Epoch 26/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9943 - mean_io_u_5: 0.8604 - dice_coef: 0.6981 - precision: 0.9959 - sensitivity: 0.9930 - specificity: 0.9986 - dice_coef_necrotic: 0.4178 - dice_coef_edema: 0.6799 - dice_coef_enhancing: 0.6963
# Epoch 26: val_loss did not improve from 0.01739
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0174 - accuracy: 0.9943 - mean_io_u_5: 0.8604 - dice_coef: 0.6981 - precision: 0.9959 - sensitivity: 0.9930 - specificity: 0.9986 - dice_coef_necrotic: 0.4178 - dice_coef_edema: 0.6799 - dice_coef_enhancing: 0.6963 - val_loss: 0.0214 - val_accuracy: 0.9929 - val_mean_io_u_5: 0.8538 - val_dice_coef: 0.6877 - val_precision: 0.9946 - val_sensitivity: 0.9916 - val_specificity: 0.9982 - val_dice_coef_necrotic: 0.3746 - val_dice_coef_edema: 0.6888 - val_dice_coef_enhancing: 0.6891 - lr: 0.0010
# Epoch 27/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9947 - mean_io_u_5: 0.8640 - dice_coef: 0.7147 - precision: 0.9962 - sensitivity: 0.9935 - specificity: 0.9988 - dice_coef_necrotic: 0.4423 - dice_coef_edema: 0.7074 - dice_coef_enhancing: 0.7104
# Epoch 27: val_loss improved from 0.01739 to 0.01695, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.27-0.016953.m5
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0156 - accuracy: 0.9947 - mean_io_u_5: 0.8640 - dice_coef: 0.7147 - precision: 0.9962 - sensitivity: 0.9935 - specificity: 0.9988 - dice_coef_necrotic: 0.4423 - dice_coef_edema: 0.7074 - dice_coef_enhancing: 0.7104 - val_loss: 0.0170 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8657 - val_dice_coef: 0.7062 - val_precision: 0.9959 - val_sensitivity: 0.9932 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4261 - val_dice_coef_edema: 0.7068 - val_dice_coef_enhancing: 0.6934 - lr: 0.0010
# Epoch 28/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9948 - mean_io_u_5: 0.8514 - dice_coef: 0.7172 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4419 - dice_coef_edema: 0.7133 - dice_coef_enhancing: 0.7146
# Epoch 28: val_loss did not improve from 0.01695
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0154 - accuracy: 0.9948 - mean_io_u_5: 0.8514 - dice_coef: 0.7172 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4419 - dice_coef_edema: 0.7133 - dice_coef_enhancing: 0.7146 - val_loss: 0.0181 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8700 - val_dice_coef: 0.7090 - val_precision: 0.9957 - val_sensitivity: 0.9934 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4527 - val_dice_coef_edema: 0.7159 - val_dice_coef_enhancing: 0.6687 - lr: 0.0010
# Epoch 29/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9942 - mean_io_u_5: 0.8575 - dice_coef: 0.6934 - precision: 0.9958 - sensitivity: 0.9929 - specificity: 0.9986 - dice_coef_necrotic: 0.4161 - dice_coef_edema: 0.6757 - dice_coef_enhancing: 0.6831
# Epoch 29: val_loss did not improve from 0.01695
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0179 - accuracy: 0.9942 - mean_io_u_5: 0.8575 - dice_coef: 0.6934 - precision: 0.9958 - sensitivity: 0.9929 - specificity: 0.9986 - dice_coef_necrotic: 0.4161 - dice_coef_edema: 0.6757 - dice_coef_enhancing: 0.6831 - val_loss: 0.0170 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8433 - val_dice_coef: 0.7303 - val_precision: 0.9962 - val_sensitivity: 0.9929 - val_specificity: 0.9987 - val_dice_coef_necrotic: 0.4833 - val_dice_coef_edema: 0.7000 - val_dice_coef_enhancing: 0.7391 - lr: 0.0010
# Epoch 30/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9948 - mean_io_u_5: 0.8615 - dice_coef: 0.7186 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4502 - dice_coef_edema: 0.7138 - dice_coef_enhancing: 0.7116
# Epoch 30: val_loss did not improve from 0.01695
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0156 - accuracy: 0.9948 - mean_io_u_5: 0.8615 - dice_coef: 0.7186 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4502 - dice_coef_edema: 0.7138 - dice_coef_enhancing: 0.7116 - val_loss: 0.0222 - val_accuracy: 0.9931 - val_mean_io_u_5: 0.8688 - val_dice_coef: 0.6583 - val_precision: 0.9949 - val_sensitivity: 0.9916 - val_specificity: 0.9983 - val_dice_coef_necrotic: 0.3747 - val_dice_coef_edema: 0.6243 - val_dice_coef_enhancing: 0.6359 - lr: 0.0010
# Epoch 31/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9947 - mean_io_u_5: 0.8618 - dice_coef: 0.7126 - precision: 0.9962 - sensitivity: 0.9934 - specificity: 0.9987 - dice_coef_necrotic: 0.4429 - dice_coef_edema: 0.7049 - dice_coef_enhancing: 0.7037
# Epoch 31: val_loss improved from 0.01695 to 0.01594, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.31-0.015938.m5
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0160 - accuracy: 0.9947 - mean_io_u_5: 0.8618 - dice_coef: 0.7126 - precision: 0.9962 - sensitivity: 0.9934 - specificity: 0.9987 - dice_coef_necrotic: 0.4429 - dice_coef_edema: 0.7049 - dice_coef_enhancing: 0.7037 - val_loss: 0.0159 - val_accuracy: 0.9948 - val_mean_io_u_5: 0.8601 - val_dice_coef: 0.7228 - val_precision: 0.9963 - val_sensitivity: 0.9935 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4336 - val_dice_coef_edema: 0.7076 - val_dice_coef_enhancing: 0.7513 - lr: 0.0010
# Epoch 32/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9947 - mean_io_u_5: 0.8619 - dice_coef: 0.7118 - precision: 0.9963 - sensitivity: 0.9934 - specificity: 0.9988 - dice_coef_necrotic: 0.4444 - dice_coef_edema: 0.7047 - dice_coef_enhancing: 0.6994
# Epoch 32: val_loss did not improve from 0.01594
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0158 - accuracy: 0.9947 - mean_io_u_5: 0.8619 - dice_coef: 0.7118 - precision: 0.9963 - sensitivity: 0.9934 - specificity: 0.9988 - dice_coef_necrotic: 0.4444 - dice_coef_edema: 0.7047 - dice_coef_enhancing: 0.6994 - val_loss: 0.0174 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8526 - val_dice_coef: 0.7202 - val_precision: 0.9957 - val_sensitivity: 0.9935 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4399 - val_dice_coef_edema: 0.7148 - val_dice_coef_enhancing: 0.7275 - lr: 0.0010
# Epoch 33/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9950 - mean_io_u_5: 0.8516 - dice_coef: 0.7263 - precision: 0.9964 - sensitivity: 0.9938 - specificity: 0.9988 - dice_coef_necrotic: 0.4602 - dice_coef_edema: 0.7235 - dice_coef_enhancing: 0.7226
# Epoch 33: val_loss did not improve from 0.01594
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0148 - accuracy: 0.9950 - mean_io_u_5: 0.8516 - dice_coef: 0.7263 - precision: 0.9964 - sensitivity: 0.9938 - specificity: 0.9988 - dice_coef_necrotic: 0.4602 - dice_coef_edema: 0.7235 - dice_coef_enhancing: 0.7226 - val_loss: 0.0166 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8429 - val_dice_coef: 0.7290 - val_precision: 0.9961 - val_sensitivity: 0.9931 - val_specificity: 0.9987 - val_dice_coef_necrotic: 0.4721 - val_dice_coef_edema: 0.7072 - val_dice_coef_enhancing: 0.7381 - lr: 0.0010
# Epoch 34/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9948 - mean_io_u_5: 0.8534 - dice_coef: 0.7140 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4442 - dice_coef_edema: 0.7092 - dice_coef_enhancing: 0.7038
# Epoch 34: val_loss did not improve from 0.01594
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0156 - accuracy: 0.9948 - mean_io_u_5: 0.8534 - dice_coef: 0.7140 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4442 - dice_coef_edema: 0.7092 - dice_coef_enhancing: 0.7038 - val_loss: 0.0172 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8543 - val_dice_coef: 0.7041 - val_precision: 0.9957 - val_sensitivity: 0.9934 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4322 - val_dice_coef_edema: 0.6893 - val_dice_coef_enhancing: 0.6962 - lr: 0.0010
# Epoch 35/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9949 - mean_io_u_5: 0.8544 - dice_coef: 0.7217 - precision: 0.9963 - sensitivity: 0.9937 - specificity: 0.9988 - dice_coef_necrotic: 0.4601 - dice_coef_edema: 0.7146 - dice_coef_enhancing: 0.7135
# Epoch 35: val_loss did not improve from 0.01594
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0153 - accuracy: 0.9949 - mean_io_u_5: 0.8544 - dice_coef: 0.7217 - precision: 0.9963 - sensitivity: 0.9937 - specificity: 0.9988 - dice_coef_necrotic: 0.4601 - dice_coef_edema: 0.7146 - dice_coef_enhancing: 0.7135 - val_loss: 0.0176 - val_accuracy: 0.9944 - val_mean_io_u_5: 0.8507 - val_dice_coef: 0.7062 - val_precision: 0.9958 - val_sensitivity: 0.9933 - val_specificity: 0.9986 - val_dice_coef_necrotic: 0.4627 - val_dice_coef_edema: 0.7079 - val_dice_coef_enhancing: 0.6554 - lr: 0.0010
# Epoch 36/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9948 - mean_io_u_5: 0.8463 - dice_coef: 0.7196 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4537 - dice_coef_edema: 0.7140 - dice_coef_enhancing: 0.7121
# Epoch 36: val_loss did not improve from 0.01594
# 850/850 [==============================] - 282s 332ms/step - loss: 0.0155 - accuracy: 0.9948 - mean_io_u_5: 0.8463 - dice_coef: 0.7196 - precision: 0.9963 - sensitivity: 0.9936 - specificity: 0.9988 - dice_coef_necrotic: 0.4537 - dice_coef_edema: 0.7140 - dice_coef_enhancing: 0.7121 - val_loss: 0.0173 - val_accuracy: 0.9942 - val_mean_io_u_5: 0.8412 - val_dice_coef: 0.7019 - val_precision: 0.9959 - val_sensitivity: 0.9929 - val_specificity: 0.9987 - val_dice_coef_necrotic: 0.4491 - val_dice_coef_edema: 0.7172 - val_dice_coef_enhancing: 0.6426 - lr: 0.0010
# Epoch 37/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9951 - mean_io_u_5: 0.8472 - dice_coef: 0.7279 - precision: 0.9966 - sensitivity: 0.9939 - specificity: 0.9989 - dice_coef_necrotic: 0.4599 - dice_coef_edema: 0.7315 - dice_coef_enhancing: 0.7212
# Epoch 37: val_loss did not improve from 0.01594
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0144 - accuracy: 0.9951 - mean_io_u_5: 0.8472 - dice_coef: 0.7279 - precision: 0.9966 - sensitivity: 0.9939 - specificity: 0.9989 - dice_coef_necrotic: 0.4599 - dice_coef_edema: 0.7315 - dice_coef_enhancing: 0.7212 - val_loss: 0.0187 - val_accuracy: 0.9941 - val_mean_io_u_5: 0.8495 - val_dice_coef: 0.7085 - val_precision: 0.9955 - val_sensitivity: 0.9931 - val_specificity: 0.9985 - val_dice_coef_necrotic: 0.4464 - val_dice_coef_edema: 0.7244 - val_dice_coef_enhancing: 0.6648 - lr: 0.0010
# Epoch 38/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9950 - mean_io_u_5: 0.8555 - dice_coef: 0.7270 - precision: 0.9964 - sensitivity: 0.9938 - specificity: 0.9988 - dice_coef_necrotic: 0.4621 - dice_coef_edema: 0.7253 - dice_coef_enhancing: 0.7216
# Epoch 38: val_loss did not improve from 0.01594
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0149 - accuracy: 0.9950 - mean_io_u_5: 0.8555 - dice_coef: 0.7270 - precision: 0.9964 - sensitivity: 0.9938 - specificity: 0.9988 - dice_coef_necrotic: 0.4621 - dice_coef_edema: 0.7253 - dice_coef_enhancing: 0.7216 - val_loss: 0.0216 - val_accuracy: 0.9930 - val_mean_io_u_5: 0.8502 - val_dice_coef: 0.7059 - val_precision: 0.9943 - val_sensitivity: 0.9920 - val_specificity: 0.9981 - val_dice_coef_necrotic: 0.4433 - val_dice_coef_edema: 0.6927 - val_dice_coef_enhancing: 0.6895 - lr: 0.0010
# Epoch 39/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9950 - mean_io_u_5: 0.8599 - dice_coef: 0.7288 - precision: 0.9965 - sensitivity: 0.9939 - specificity: 0.9988 - dice_coef_necrotic: 0.4677 - dice_coef_edema: 0.7262 - dice_coef_enhancing: 0.7225
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 39: val_loss did not improve from 0.01594
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0148 - accuracy: 0.9950 - mean_io_u_5: 0.8599 - dice_coef: 0.7288 - precision: 0.9965 - sensitivity: 0.9939 - specificity: 0.9988 - dice_coef_necrotic: 0.4677 - dice_coef_edema: 0.7262 - dice_coef_enhancing: 0.7225 - val_loss: 0.0176 - val_accuracy: 0.9943 - val_mean_io_u_5: 0.8581 - val_dice_coef: 0.7070 - val_precision: 0.9956 - val_sensitivity: 0.9935 - val_specificity: 0.9985 - val_dice_coef_necrotic: 0.3990 - val_dice_coef_edema: 0.6896 - val_dice_coef_enhancing: 0.7410 - lr: 0.0010
# Epoch 40/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9954 - mean_io_u_5: 0.8524 - dice_coef: 0.7454 - precision: 0.9967 - sensitivity: 0.9943 - specificity: 0.9989 - dice_coef_necrotic: 0.4866 - dice_coef_edema: 0.7486 - dice_coef_enhancing: 0.7475
# Epoch 40: val_loss improved from 0.01594 to 0.01518, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.40-0.015182.m5
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0135 - accuracy: 0.9954 - mean_io_u_5: 0.8524 - dice_coef: 0.7454 - precision: 0.9967 - sensitivity: 0.9943 - specificity: 0.9989 - dice_coef_necrotic: 0.4866 - dice_coef_edema: 0.7486 - dice_coef_enhancing: 0.7475 - val_loss: 0.0152 - val_accuracy: 0.9950 - val_mean_io_u_5: 0.8557 - val_dice_coef: 0.7430 - val_precision: 0.9963 - val_sensitivity: 0.9940 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4811 - val_dice_coef_edema: 0.7407 - val_dice_coef_enhancing: 0.7515 - lr: 2.0000e-04
# Epoch 41/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9955 - mean_io_u_5: 0.8564 - dice_coef: 0.7500 - precision: 0.9968 - sensitivity: 0.9945 - specificity: 0.9989 - dice_coef_necrotic: 0.4943 - dice_coef_edema: 0.7571 - dice_coef_enhancing: 0.7494
# Epoch 41: val_loss did not improve from 0.01518
# 850/850 [==============================] - 283s 332ms/step - loss: 0.0129 - accuracy: 0.9955 - mean_io_u_5: 0.8564 - dice_coef: 0.7500 - precision: 0.9968 - sensitivity: 0.9945 - specificity: 0.9989 - dice_coef_necrotic: 0.4943 - dice_coef_edema: 0.7571 - dice_coef_enhancing: 0.7494 - val_loss: 0.0152 - val_accuracy: 0.9949 - val_mean_io_u_5: 0.8529 - val_dice_coef: 0.7481 - val_precision: 0.9962 - val_sensitivity: 0.9939 - val_specificity: 0.9987 - val_dice_coef_necrotic: 0.4951 - val_dice_coef_edema: 0.7405 - val_dice_coef_enhancing: 0.7579 - lr: 2.0000e-04
# Epoch 42/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9956 - mean_io_u_5: 0.8561 - dice_coef: 0.7523 - precision: 0.9969 - sensitivity: 0.9946 - specificity: 0.9990 - dice_coef_necrotic: 0.4982 - dice_coef_edema: 0.7608 - dice_coef_enhancing: 0.7511
# Epoch 42: val_loss improved from 0.01518 to 0.01465, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.42-0.014651.m5
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0126 - accuracy: 0.9956 - mean_io_u_5: 0.8561 - dice_coef: 0.7523 - precision: 0.9969 - sensitivity: 0.9946 - specificity: 0.9990 - dice_coef_necrotic: 0.4982 - dice_coef_edema: 0.7608 - dice_coef_enhancing: 0.7511 - val_loss: 0.0147 - val_accuracy: 0.9952 - val_mean_io_u_5: 0.8660 - val_dice_coef: 0.7471 - val_precision: 0.9963 - val_sensitivity: 0.9944 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4832 - val_dice_coef_edema: 0.7493 - val_dice_coef_enhancing: 0.7569 - lr: 2.0000e-04
# Epoch 43/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9957 - mean_io_u_5: 0.8631 - dice_coef: 0.7527 - precision: 0.9969 - sensitivity: 0.9946 - specificity: 0.9990 - dice_coef_necrotic: 0.4972 - dice_coef_edema: 0.7645 - dice_coef_enhancing: 0.7499
# Epoch 43: val_loss did not improve from 0.01465
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0124 - accuracy: 0.9957 - mean_io_u_5: 0.8631 - dice_coef: 0.7527 - precision: 0.9969 - sensitivity: 0.9946 - specificity: 0.9990 - dice_coef_necrotic: 0.4972 - dice_coef_edema: 0.7645 - dice_coef_enhancing: 0.7499 - val_loss: 0.0147 - val_accuracy: 0.9951 - val_mean_io_u_5: 0.8567 - val_dice_coef: 0.7464 - val_precision: 0.9963 - val_sensitivity: 0.9943 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4780 - val_dice_coef_edema: 0.7469 - val_dice_coef_enhancing: 0.7620 - lr: 2.0000e-04
# Epoch 44/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9957 - mean_io_u_5: 0.8619 - dice_coef: 0.7553 - precision: 0.9970 - sensitivity: 0.9947 - specificity: 0.9990 - dice_coef_necrotic: 0.5026 - dice_coef_edema: 0.7674 - dice_coef_enhancing: 0.7521
# Epoch 44: val_loss improved from 0.01465 to 0.01428, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.44-0.014285.m5
# 850/850 [==============================] - 284s 333ms/step - loss: 0.0123 - accuracy: 0.9957 - mean_io_u_5: 0.8619 - dice_coef: 0.7553 - precision: 0.9970 - sensitivity: 0.9947 - specificity: 0.9990 - dice_coef_necrotic: 0.5026 - dice_coef_edema: 0.7674 - dice_coef_enhancing: 0.7521 - val_loss: 0.0143 - val_accuracy: 0.9952 - val_mean_io_u_5: 0.8556 - val_dice_coef: 0.7523 - val_precision: 0.9964 - val_sensitivity: 0.9943 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4967 - val_dice_coef_edema: 0.7528 - val_dice_coef_enhancing: 0.7610 - lr: 2.0000e-04
# Epoch 45/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9957 - mean_io_u_5: 0.8649 - dice_coef: 0.7561 - precision: 0.9970 - sensitivity: 0.9947 - specificity: 0.9990 - dice_coef_necrotic: 0.5038 - dice_coef_edema: 0.7684 - dice_coef_enhancing: 0.7532
# Epoch 45: val_loss improved from 0.01428 to 0.01382, saving model to C:/Users/Computing/Desktop/archive\3D-UNet-2021model_.45-0.013822.m5
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0123 - accuracy: 0.9957 - mean_io_u_5: 0.8649 - dice_coef: 0.7561 - precision: 0.9970 - sensitivity: 0.9947 - specificity: 0.9990 - dice_coef_necrotic: 0.5038 - dice_coef_edema: 0.7684 - dice_coef_enhancing: 0.7532 - val_loss: 0.0138 - val_accuracy: 0.9953 - val_mean_io_u_5: 0.8677 - val_dice_coef: 0.7533 - val_precision: 0.9966 - val_sensitivity: 0.9944 - val_specificity: 0.9989 - val_dice_coef_necrotic: 0.4949 - val_dice_coef_edema: 0.7476 - val_dice_coef_enhancing: 0.7719 - lr: 2.0000e-04
# Epoch 46/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9958 - mean_io_u_5: 0.8689 - dice_coef: 0.7591 - precision: 0.9970 - sensitivity: 0.9948 - specificity: 0.9990 - dice_coef_necrotic: 0.5078 - dice_coef_edema: 0.7736 - dice_coef_enhancing: 0.7558
# Epoch 46: val_loss did not improve from 0.01382
# 850/850 [==============================] - 283s 333ms/step - loss: 0.0120 - accuracy: 0.9958 - mean_io_u_5: 0.8689 - dice_coef: 0.7591 - precision: 0.9970 - sensitivity: 0.9948 - specificity: 0.9990 - dice_coef_necrotic: 0.5078 - dice_coef_edema: 0.7736 - dice_coef_enhancing: 0.7558 - val_loss: 0.0153 - val_accuracy: 0.9951 - val_mean_io_u_5: 0.8670 - val_dice_coef: 0.7416 - val_precision: 0.9962 - val_sensitivity: 0.9943 - val_specificity: 0.9987 - val_dice_coef_necrotic: 0.4734 - val_dice_coef_edema: 0.7506 - val_dice_coef_enhancing: 0.7436 - lr: 2.0000e-04
# Epoch 47/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9958 - mean_io_u_5: 0.8661 - dice_coef: 0.7591 - precision: 0.9971 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5083 - dice_coef_edema: 0.7741 - dice_coef_enhancing: 0.7551
# Epoch 47: val_loss did not improve from 0.01382
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0119 - accuracy: 0.9958 - mean_io_u_5: 0.8661 - dice_coef: 0.7591 - precision: 0.9971 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5083 - dice_coef_edema: 0.7741 - dice_coef_enhancing: 0.7551 - val_loss: 0.0142 - val_accuracy: 0.9952 - val_mean_io_u_5: 0.8553 - val_dice_coef: 0.7511 - val_precision: 0.9964 - val_sensitivity: 0.9943 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4898 - val_dice_coef_edema: 0.7529 - val_dice_coef_enhancing: 0.7625 - lr: 2.0000e-04
# Epoch 48/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9958 - mean_io_u_5: 0.8615 - dice_coef: 0.7600 - precision: 0.9970 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5103 - dice_coef_edema: 0.7743 - dice_coef_enhancing: 0.7563
# Epoch 48: val_loss did not improve from 0.01382
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0119 - accuracy: 0.9958 - mean_io_u_5: 0.8615 - dice_coef: 0.7600 - precision: 0.9970 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5103 - dice_coef_edema: 0.7743 - dice_coef_enhancing: 0.7563 - val_loss: 0.0150 - val_accuracy: 0.9950 - val_mean_io_u_5: 0.8531 - val_dice_coef: 0.7472 - val_precision: 0.9963 - val_sensitivity: 0.9941 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5008 - val_dice_coef_edema: 0.7511 - val_dice_coef_enhancing: 0.7379 - lr: 2.0000e-04
# Epoch 49/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9959 - mean_io_u_5: 0.8677 - dice_coef: 0.7613 - precision: 0.9971 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5107 - dice_coef_edema: 0.7791 - dice_coef_enhancing: 0.7565
# Epoch 49: val_loss did not improve from 0.01382
# 850/850 [==============================] - 285s 335ms/step - loss: 0.0117 - accuracy: 0.9959 - mean_io_u_5: 0.8677 - dice_coef: 0.7613 - precision: 0.9971 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5107 - dice_coef_edema: 0.7791 - dice_coef_enhancing: 0.7565 - val_loss: 0.0141 - val_accuracy: 0.9953 - val_mean_io_u_5: 0.8655 - val_dice_coef: 0.7493 - val_precision: 0.9965 - val_sensitivity: 0.9944 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4929 - val_dice_coef_edema: 0.7504 - val_dice_coef_enhancing: 0.7549 - lr: 2.0000e-04
# Epoch 50/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9959 - mean_io_u_5: 0.8702 - dice_coef: 0.7617 - precision: 0.9971 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5124 - dice_coef_edema: 0.7766 - dice_coef_enhancing: 0.7587
# Epoch 50: val_loss did not improve from 0.01382
# 850/850 [==============================] - 285s 335ms/step - loss: 0.0118 - accuracy: 0.9959 - mean_io_u_5: 0.8702 - dice_coef: 0.7617 - precision: 0.9971 - sensitivity: 0.9949 - specificity: 0.9990 - dice_coef_necrotic: 0.5124 - dice_coef_edema: 0.7766 - dice_coef_enhancing: 0.7587 - val_loss: 0.0143 - val_accuracy: 0.9953 - val_mean_io_u_5: 0.8702 - val_dice_coef: 0.7538 - val_precision: 0.9964 - val_sensitivity: 0.9944 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4995 - val_dice_coef_edema: 0.7562 - val_dice_coef_enhancing: 0.7606 - lr: 2.0000e-04
# Epoch 51/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9959 - mean_io_u_5: 0.8707 - dice_coef: 0.7638 - precision: 0.9971 - sensitivity: 0.9950 - specificity: 0.9990 - dice_coef_necrotic: 0.5144 - dice_coef_edema: 0.7817 - dice_coef_enhancing: 0.7601
# Epoch 51: val_loss did not improve from 0.01382
# 850/850 [==============================] - 284s 334ms/step - loss: 0.0116 - accuracy: 0.9959 - mean_io_u_5: 0.8707 - dice_coef: 0.7638 - precision: 0.9971 - sensitivity: 0.9950 - specificity: 0.9990 - dice_coef_necrotic: 0.5144 - dice_coef_edema: 0.7817 - dice_coef_enhancing: 0.7601 - val_loss: 0.0142 - val_accuracy: 0.9953 - val_mean_io_u_5: 0.8740 - val_dice_coef: 0.7493 - val_precision: 0.9965 - val_sensitivity: 0.9945 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.4847 - val_dice_coef_edema: 0.7538 - val_dice_coef_enhancing: 0.7596 - lr: 2.0000e-04
# Epoch 52/100
# ...
# Epoch 69/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8747 - dice_coef: 0.7722 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5292 - dice_coef_edema: 0.7941 - dice_coef_enhancing: 0.7665
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 69: val_loss did not improve from 0.01382
# 850/850 [==============================] - 292s 343ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8747 - dice_coef: 0.7722 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5292 - dice_coef_edema: 0.7941 - dice_coef_enhancing: 0.7665 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7568 - val_precision: 0.9965 - val_sensitivity: 0.9945 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5030 - val_dice_coef_edema: 0.7604 - val_dice_coef_enhancing: 0.7649 - lr: 8.0000e-06
# Epoch 70/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8751 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7939 - dice_coef_enhancing: 0.7674
# Epoch 70: val_loss did not improve from 0.01382
# 850/850 [==============================] - 290s 341ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8751 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7939 - dice_coef_enhancing: 0.7674 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7567 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5032 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7641 - lr: 1.6000e-06
# Epoch 71/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8750 - dice_coef: 0.7713 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5264 - dice_coef_edema: 0.7935 - dice_coef_enhancing: 0.7659
# Epoch 71: val_loss did not improve from 0.01382
# 850/850 [==============================] - 289s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8750 - dice_coef: 0.7713 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5264 - dice_coef_edema: 0.7935 - dice_coef_enhancing: 0.7659 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7567 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5028 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7643 - lr: 1.6000e-06
# Epoch 72/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8750 - dice_coef: 0.7722 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7944 - dice_coef_enhancing: 0.7682
# Epoch 72: val_loss did not improve from 0.01382
# 850/850 [==============================] - 287s 338ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8750 - dice_coef: 0.7722 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7944 - dice_coef_enhancing: 0.7682 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7567 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5031 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7641 - lr: 1.6000e-06
# Epoch 73/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7717 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5273 - dice_coef_edema: 0.7940 - dice_coef_enhancing: 0.7662
# Epoch 73: val_loss did not improve from 0.01382
# 850/850 [==============================] - 289s 340ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7717 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5273 - dice_coef_edema: 0.7940 - dice_coef_enhancing: 0.7662 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8712 - val_dice_coef: 0.7568 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5032 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7645 - lr: 1.6000e-06
# Epoch 74/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8755 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7937 - dice_coef_enhancing: 0.7677
# Epoch 74: val_loss did not improve from 0.01382
# 850/850 [==============================] - 289s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8755 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7937 - dice_coef_enhancing: 0.7677 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7568 - val_precision: 0.9965 - val_sensitivity: 0.9945 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5032 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7643 - lr: 1.6000e-06
# Epoch 75/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8750 - dice_coef: 0.7721 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7946 - dice_coef_enhancing: 0.7672
# Epoch 75: val_loss did not improve from 0.01382
# 850/850 [==============================] - 288s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8750 - dice_coef: 0.7721 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7946 - dice_coef_enhancing: 0.7672 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7569 - val_precision: 0.9965 - val_sensitivity: 0.9945 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5034 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7647 - lr: 1.6000e-06
# Epoch 76/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7717 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7943 - dice_coef_enhancing: 0.7660
# Epoch 76: val_loss did not improve from 0.01382
# 850/850 [==============================] - 288s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7717 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7943 - dice_coef_enhancing: 0.7660 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7569 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5034 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7646 - lr: 1.6000e-06
# Epoch 77/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7722 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7947 - dice_coef_enhancing: 0.7674
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 77: val_loss did not improve from 0.01382
# 850/850 [==============================] - 288s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7722 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7947 - dice_coef_enhancing: 0.7674 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8712 - val_dice_coef: 0.7568 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5034 - val_dice_coef_edema: 0.7607 - val_dice_coef_enhancing: 0.7643 - lr: 1.6000e-06
# Epoch 78/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5278 - dice_coef_edema: 0.7944 - dice_coef_enhancing: 0.7666
# Epoch 78: val_loss did not improve from 0.01382
# 850/850 [==============================] - 288s 338ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5278 - dice_coef_edema: 0.7944 - dice_coef_enhancing: 0.7666 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8712 - val_dice_coef: 0.7568 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5032 - val_dice_coef_edema: 0.7607 - val_dice_coef_enhancing: 0.7643 - lr: 1.0000e-06
# Epoch 79/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8751 - dice_coef: 0.7721 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7952 - dice_coef_enhancing: 0.7669
# Epoch 79: val_loss did not improve from 0.01382
# 850/850 [==============================] - 290s 341ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8751 - dice_coef: 0.7721 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5271 - dice_coef_edema: 0.7952 - dice_coef_enhancing: 0.7669 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8713 - val_dice_coef: 0.7569 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5035 - val_dice_coef_edema: 0.7607 - val_dice_coef_enhancing: 0.7644 - lr: 1.0000e-06
# Epoch 80/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5276 - dice_coef_edema: 0.7940 - dice_coef_enhancing: 0.7673
# Epoch 80: val_loss did not improve from 0.01382
# 850/850 [==============================] - 290s 340ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5276 - dice_coef_edema: 0.7940 - dice_coef_enhancing: 0.7673 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8712 - val_dice_coef: 0.7568 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5035 - val_dice_coef_edema: 0.7607 - val_dice_coef_enhancing: 0.7641 - lr: 1.0000e-06
# Epoch 81/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7718 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5273 - dice_coef_edema: 0.7942 - dice_coef_enhancing: 0.7667
# Epoch 81: val_loss did not improve from 0.01382
# 850/850 [==============================] - 288s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7718 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5273 - dice_coef_edema: 0.7942 - dice_coef_enhancing: 0.7667 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8712 - val_dice_coef: 0.7568 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5035 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7641 - lr: 1.0000e-06
# Epoch 82/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7725 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7947 - dice_coef_enhancing: 0.7684
# Epoch 82: val_loss did not improve from 0.01382
# 850/850 [==============================] - 290s 341ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7725 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5275 - dice_coef_edema: 0.7947 - dice_coef_enhancing: 0.7684 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8712 - val_dice_coef: 0.7569 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5036 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7643 - lr: 1.0000e-06
# Epoch 83/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8751 - dice_coef: 0.7719 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5278 - dice_coef_edema: 0.7946 - dice_coef_enhancing: 0.7661
# Epoch 83: val_loss did not improve from 0.01382
# 850/850 [==============================] - 288s 338ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8751 - dice_coef: 0.7719 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5278 - dice_coef_edema: 0.7946 - dice_coef_enhancing: 0.7661 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8712 - val_dice_coef: 0.7569 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5035 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7645 - lr: 1.0000e-06
# Epoch 84/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5280 - dice_coef_edema: 0.7941 - dice_coef_enhancing: 0.7665
# Epoch 84: val_loss did not improve from 0.01382
# 850/850 [==============================] - 288s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8752 - dice_coef: 0.7720 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5280 - dice_coef_edema: 0.7941 - dice_coef_enhancing: 0.7665 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8711 - val_dice_coef: 0.7569 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5037 - val_dice_coef_edema: 0.7606 - val_dice_coef_enhancing: 0.7645 - lr: 1.0000e-06
# Epoch 85/100
# 850/850 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7719 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5276 - dice_coef_edema: 0.7939 - dice_coef_enhancing: 0.7669
# Epoch 85: val_loss did not improve from 0.01382
# 850/850 [==============================] - 289s 339ms/step - loss: 0.0109 - accuracy: 0.9961 - mean_io_u_5: 0.8753 - dice_coef: 0.7719 - precision: 0.9973 - sensitivity: 0.9952 - specificity: 0.9991 - dice_coef_necrotic: 0.5276 - dice_coef_edema: 0.7939 - dice_coef_enhancing: 0.7669 - val_loss: 0.0142 - val_accuracy: 0.9954 - val_mean_io_u_5: 0.8713 - val_dice_coef: 0.7569 - val_precision: 0.9965 - val_sensitivity: 0.9946 - val_specificity: 0.9988 - val_dice_coef_necrotic: 0.5035 - val_dice_coef_edema: 0.7607 - val_dice_coef_enhancing: 0.7645 - lr: 1.0000e-06
# Epoch 85: early stopping

# %%
print("Evaluate on test data")
results = model1.evaluate(test_generator, callbacks= callbacks)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 150/150 [==============================] - 37s 246ms/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_5: 0.8694 - dice_coef: 0.7315 - precision: 0.9960 - sensitivity: 0.9940 - specificity: 0.9987 - dice_coef_necrotic: 0.4813 - dice_coef_edema: 0.7333 - dice_coef_enhancing: 0.7124
# test loss, test acc: [0.015970751643180847, 0.9948136210441589, 0.8694289922714233, 0.7314507365226746, 0.9959919452667236, 0.99396151304245, 0.9986681342124939, 0.48131272196769714, 0.7333204746246338, 0.7123534083366394]

# %%
print("Evaluate on val data")
results = model1.evaluate(valid_generator, callbacks= callbacks)
print("val loss, val acc:", results)
# Out:
# Evaluate on val data
# 251/251 [==============================] - 62s 247ms/step - loss: 0.0142 - accuracy: 0.9954 - mean_io_u_5: 0.8713 - dice_coef: 0.7569 - precision: 0.9965 - sensitivity: 0.9946 - specificity: 0.9988 - dice_coef_necrotic: 0.5035 - dice_coef_edema: 0.7607 - dice_coef_enhancing: 0.7645
# val loss, val acc: [0.01416836865246296, 0.9953837394714355, 0.8712506294250488, 0.7569038271903992, 0.9964852333068848, 0.9945586323738098, 0.9988313317298889, 0.5034840106964111, 0.760688841342926, 0.7644568681716919]

# %%
model = tf.keras.models.load_model('C:/Users/Computing/Desktop/archive/model_3dUnet_8layer_2mod.h5', 
                                   custom_objects={ 'accuracy' : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef": dice_coef,
                                                   "precision": precision,
                                                   "sensitivity":sensitivity,
                                                   "specificity":specificity,
                                                   "dice_coef_necrotic": dice_coef_necrotic,
                                                   "dice_coef_edema": dice_coef_edema,
                                                   "dice_coef_enhancing": dice_coef_enhancing
                                                  }, compile=False)

# %%
import pandas as pd
history = pd.read_csv(r'C:/Users/Computing/Desktop/archive/training.log', sep=',', engine='python')

hist=history

# %%
# Reports the AUC of a model outputting a probability.
model.compile(optimizer='Adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.AUC()])

# Reports the AUC of a model outputting a logit.
model.compile(optimizer='Adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=[tf.keras.metrics.AUC(from_logits=True)])

# %%
# hist=history.history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u_5'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u_5'],'r',label='Validation mean IOU')
ax[3].legend()


plt.savefig('training_result_2021.png')
plt.show()
